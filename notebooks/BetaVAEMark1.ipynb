# %%
import torch 
import torch.nn as nn # Contains neural network layers.
import torch.optim as optim # Contains Optimisers.
from torch.utils.data import DataLoader 
import torch.nn.functional as F # Contains stateless functions (no internel parameters)
from torchinfo import summary # To get network description
import numpy as np
import wandb # W & B Tracking
import matplotlib.pyplot as plt
import ad_tools.tools as tools # Custom build tools for project
import awkward as ak

# Use GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') 
print(device)
# Out:
# cpu

# %%
images = ak.from_parquet("/home/xzcapask/atlas_ad_hllhc/data/atlas_calorimeter_images/JZ0_no_filter.parquet", row_groups = range(15))
# Out:
# ---------------------------------------------------------------------------
# ArrowMemoryError                          Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 images = ak.from_parquet("/home/xzcapask/atlas_ad_hllhc/data/atlas_calorimeter_images/JZ0_no_filter.parquet", row_groups = range(15))
#
# File ~/atlas_ad_hllhc/env/lib/python3.10/site-packages/awkward/_dispatch.py:41, in named_high_level_function.<locals>.dispatch(*args, **kwargs)
#      38 @wraps(func)
#      39 def dispatch(*args, **kwargs):
#      40     # NOTE: this decorator assumes that the operation is exposed under `ak.`
# ---> 41     with OperationErrorContext(name, args, kwargs):
#      42         gen_or_result = func(*args, **kwargs)
#      43         if isgenerator(gen_or_result):
#
# File ~/atlas_ad_hllhc/env/lib/python3.10/site-packages/awkward/_errors.py:80, in ErrorContext.__exit__(self, exception_type, exception_value, traceback)
#      78     self._slate.__dict__.clear()
#      79     # Handle caught exception
# ---> 80     raise self.decorate_exception(exception_type, exception_value)
#      81 else:
#      82     # Step out of the way so that another ErrorContext can become primary.
#      83     if self.primary() is self:
#
# File ~/atlas_ad_hllhc/env/lib/python3.10/site-packages/awkward/_dispatch.py:42, in named_high_level_function.<locals>.dispatch(*args, **kwargs)
#      38 @wraps(func)
#      39 def dispatch(*args, **kwargs):
#      40     # NOTE: this decorator assumes that the operation is exposed under `ak.`
#      41     with OperationErrorContext(name, args, kwargs):
# ---> 42         gen_or_result = func(*args, **kwargs)
#      43         if isgenerator(gen_or_result):
#      44             array_likes = next(gen_or_result)
#
# File ~/atlas_ad_hllhc/env/lib/python3.10/site-packages/awkward/operations/ak_from_parquet.py:74, in from_parquet(path, columns, row_groups, storage_options, max_gap, max_block, footer_sample_size, generate_bitmasks, highlevel, behavior, attrs)
#      34 """
#      35 Args:
#      36     path (str): Local filename or remote URL, passed to fsspec for resolution.
#    (...)
#      68 See also #ak.to_parquet, #ak.metadata_from_parquet.
#      69 """
#      71 parquet_columns, subform, actual_paths, fs, subrg, row_counts, meta, uuid = (
#      72     metadata(path, storage_options, row_groups, columns, calculate_uuid=True)
#      73 )
# ---> 74 return _load(
#      75     actual_paths,
#      76     parquet_columns if columns is not None else None,
#      77     subrg,
#      78     max_gap,
#      79     max_block,
#      80     footer_sample_size,
#      81     generate_bitmasks,
#      82     subform,
#      83     highlevel,
#      84     behavior,
#      85     fs,
#      86     attrs,
#      87 )
#
# File ~/atlas_ad_hllhc/env/lib/python3.10/site-packages/awkward/operations/ak_from_parquet.py:255, in _load(actual_paths, parquet_columns, subrg, max_gap, max_block, footer_sample_size, generate_bitmasks, subform, highlevel, behavior, fs, attrs, metadata)
#     252 arrays = []
#     253 for i, p in enumerate(actual_paths):
#     254     arrays.append(
# --> 255         _read_parquet_file(
#     256             p,
#     257             fs=fs,
#     258             parquet_columns=parquet_columns,
#     259             row_groups=subrg[i],
#     260             max_gap=max_gap,
#     261             max_block=max_block,
#     262             footer_sample_size=footer_sample_size,
#     263             generate_bitmasks=generate_bitmasks,
#     264             metadata=metadata,
#     265         )
#     266     )
#     268 assert len(arrays) != 0
#     269 if len(arrays) == 1:
#
# File ~/atlas_ad_hllhc/env/lib/python3.10/site-packages/awkward/operations/ak_from_parquet.py:334, in _read_parquet_file(path, fs, parquet_columns, row_groups, footer_sample_size, max_gap, max_block, generate_bitmasks, metadata)
#     332         arrow_table = parquetfile.read(parquet_columns)
#     333     else:
# --> 334         arrow_table = parquetfile.read_row_groups(row_groups, parquet_columns)
#     336 arrow_table = ak._connect.pyarrow.convert_native_arrow_table_to_awkward(arrow_table)
#     337 return ak.operations.ak_from_arrow._impl(
#     338     arrow_table,
#     339     generate_bitmasks,
#    (...)
#     343     None,
#     344 )
#
# File ~/atlas_ad_hllhc/env/lib/python3.10/site-packages/pyarrow/parquet/core.py:537, in ParquetFile.read_row_groups(self, row_groups, columns, use_threads, use_pandas_metadata)
#     495 """
#     496 Read a multiple row groups from a Parquet file.
#     497
#    (...)
#     533 animal: [["Flamingo","Parrot","Dog",...,"Brittle stars","Centipede"]]
#     534 """
#     535 column_indices = self._get_column_indices(
#     536     columns, use_pandas_metadata=use_pandas_metadata)
# --> 537 return self.reader.read_row_groups(row_groups,
#     538                                    column_indices=column_indices,
#     539                                    use_threads=use_threads)
#
# File ~/atlas_ad_hllhc/env/lib/python3.10/site-packages/pyarrow/_parquet.pyx:1424, in pyarrow._parquet.ParquetReader.read_row_groups()
#
# File ~/atlas_ad_hllhc/env/lib/python3.10/site-packages/pyarrow/error.pxi:91, in pyarrow.lib.check_status()
#
# ArrowMemoryError: malloc of size 4294967296 failed
#
# This error occurred while calling
#
#     ak.from_parquet(
#         '/home/xzcapask/atlas_ad_hllhc/data/atlas_calorimeter_imag'...
#         row_groups = range(0, 15)
#     )

# %%
jz0_train_dataset = tools.DatasetMaker("/home/xzcapask/atlas_ad_hllhc/data/atlas_calorimeter_images/JZ0_no_filter.parquet", up_row_num=1)
jz0_valid_dataset = tools.DatasetMaker("/home/xzcapask/atlas_ad_hllhc/data/atlas_calorimeter_images/JZ0_no_filter.parquet", low_row_num = 200, up_row_num = 201)
jz0_test_dataset = tools.DatasetMaker("/home/xzcapask/atlas_ad_hllhc/data/atlas_calorimeter_images/JZ0_no_filter.parquet", low_row_num = 205, up_row_num = 206)
ggF_test_dataset = tools.DatasetMaker("/home/xzcapask/atlas_ad_hllhc/data/atlas_calorimeter_images/ggF_SM_HH4b.parquet",up_row_num = 1)
vbf_test_dataset = tools.DatasetMaker("/home/xzcapask/atlas_ad_hllhc/data/atlas_calorimeter_images/VBF_SM_HH4b.parquet",up_row_num = 1)
hs_test_dataset = tools.DatasetMaker("/home/xzcapask/atlas_ad_hllhc/data/atlas_calorimeter_images/HZ_bbvv.parquet",up_row_num = 1)

# Datasets to test phi symmetry
# Approximately a rotation of pi/4,pi/2 and 3pi/4 in phi
transform = lambda x: torch.roll(x, shifts = 16, dims = 2)
jz0_test_pi4_dataset = tools.DatasetMaker("/home/xzcapask/atlas_ad_hllhc/data/atlas_calorimeter_images/JZ0_no_filter.parquet", low_row_num = 215, up_row_num = 216, transform = transform)
transform = lambda x: torch.roll(x, shifts = 32, dims = 2)
jz0_test_pi2_dataset = tools.DatasetMaker("/home/xzcapask/atlas_ad_hllhc/data/atlas_calorimeter_images/JZ0_no_filter.parquet", low_row_num = 225, up_row_num = 226, transform = transform)
transform = lambda x: torch.roll(x, shifts = 48, dims = 2)
jz0_test_3pi4_dataset = tools.DatasetMaker("/home/xzcapask/atlas_ad_hllhc/data/atlas_calorimeter_images/JZ0_no_filter.parquet", low_row_num = 235, up_row_num = 236, transform = transform)

# %%
jz0_train_loader = DataLoader(jz0_train_dataset, batch_size = 1000) 
jz0_valid_loader = DataLoader(jz0_valid_dataset, batch_size = 1000)
jz0_test_loader = DataLoader(jz0_test_dataset, batch_size = 1) 
ggF_test_loader = DataLoader(ggF_test_dataset, batch_size = 1)
jz0_test_pi4_loader = DataLoader(jz0_test_pi4_dataset, batch_size = 1)
jz0_test_pi2_loader = DataLoader(jz0_test_3pi4_dataset, batch_size = 1)
jz0_test_3pi4_loader = DataLoader(jz0_test_3pi4_dataset, batch_size = 1)
vbf_test_loader = DataLoader(vbf_test_dataset, batch_size = 1)
hs_test_loader = DataLoader(hs_test_dataset, batch_size = 1)

# %%
class BetaVAEMark1Encoder(nn.Module):
    """
    Encoder using standard convolutional layers.
    """
    
    def __init__(self, kernel_size = 3, latent_dim = 4):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels = 6, out_channels = 8, kernel_size = kernel_size)
        self.dropout = nn.Dropout(p = 0.2)
        self.conv2 = nn.Conv2d(in_channels = 8, out_channels = 16, kernel_size = kernel_size)
        self.conv3 = nn.Conv2d(in_channels = 16, out_channels = 32, kernel_size = kernel_size)
        self.pool = nn.MaxPool2d(2) 
        self.flatten = nn.Flatten(start_dim = 1) # Flattens images not the batch itself
        self.mu = nn.Linear(768, latent_dim)
        self.logvar = nn.Linear(768, latent_dim)
        self.circular_padding = nn.CircularPad2d((2,2,0,0))



    def forward(self,input):
        input = self.circular_padding(input)
        output1 = F.leaky_relu(self.conv1(input))
        output1 = output1[:,:,:,2:-2]
        output2 = self.pool(output1) 

        input = self.circular_padding(output2)
        output1 = F.leaky_relu(self.conv2(input))
        output1 = output1[:,:,:,2:-2]
        output2 = self.pool(output1) 

        input = self.circular_padding(output2)
        output1 = F.leaky_relu(self.conv3(input))
        output1 = output1[:,:,:,2:-2]
        output2 = self.pool(output1) 
    
        output7 = self.flatten(output2)
        mu_output = self.mu(output7)
        logvar_output = self.logvar(output7)
        return mu_output, logvar_output

class BetaVAEMark1Decoder(nn.Module):
    """
    Decoder using standard convolution layers.
    """

    def __init__(self, kernel_size = 3, latent_dim = 4):
        super().__init__()
        self.deconv1 = nn.ConvTranspose2d(in_channels = 32, out_channels = 16, kernel_size = kernel_size)
        self.deconv2 = nn.ConvTranspose2d(in_channels = 16, out_channels = 8, kernel_size = kernel_size)
        self.deconv3 = nn.ConvTranspose2d(in_channels = 8, out_channels = 6, kernel_size = kernel_size)
        self.upsample1 = nn.Upsample(size = (9,12))
        self.upsample2 = nn.Upsample(size = (22,29))
        self.upsample3 = nn.Upsample(size = (48,62))
        self.linear = nn.Linear(latent_dim,768)
        self.circular_padding = nn.CircularPad2d((2,2,0,0)) # Only adding padding in phi 

    def forward(self, input):
        output1 = self.linear(input)
        output2 = torch.reshape(output1, shape = (-1,32,4,6))

        output3 = self.upsample1(output2)
        output4 = self.circular_padding(output3)
        output5 = F.leaky_relu(self.deconv1(output4))
        output5 = output5[ : , : , : , 2:-2] # Trimming excess
        
        output6 = self.upsample2(output5)
        output7 = self.circular_padding(output6)
        output8 = F.leaky_relu(self.deconv2(output7))
        output8 = output8[:, : , : , 2:-2] # Trimming excess

        output9 = self.upsample3(output8)
        output10 = self.circular_padding(output9)
        output11 = F.leaky_relu(self.deconv3(output10))
        output12 = output11[:,:,:,2:-2]

        return output12

class BetaVAEMark1(nn.Module):
    """
    Beta VAE Mark 1.
    """
    
    def __init__(self, kernel_size = 3, latent_dim = 4):
        super().__init__()
        self.encoder = BetaVAEMark1Encoder(kernel_size = kernel_size, latent_dim = latent_dim)
        self.decoder = BetaVAEMark1Decoder(kernel_size = kernel_size, latent_dim = latent_dim)

    def reparameterise(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std) 
        return mu + eps * std
    
    def forward(self, input):
        mu, logvar = self.encoder(input)
        z = self.reparameterise(mu, logvar)
        output = self.decoder(z)
        return output, mu, logvar

# %%
input_dim = (1,6,50,64)
model = BetaVAEMark1()
summary(model, input_dim)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# BetaVAEMark1                             [1, 6, 50, 64]            --
# ├─BetaVAEMark1Encoder: 1-1               [1, 4]                    --
# │    └─CircularPad2d: 2-1                [1, 6, 50, 68]            --
# │    └─Conv2d: 2-2                       [1, 8, 48, 66]            440
# │    └─MaxPool2d: 2-3                    [1, 8, 24, 31]            --
# │    └─CircularPad2d: 2-4                [1, 8, 24, 35]            --
# │    └─Conv2d: 2-5                       [1, 16, 22, 33]           1,168
# │    └─MaxPool2d: 2-6                    [1, 16, 11, 14]           --
# │    └─CircularPad2d: 2-7                [1, 16, 11, 18]           --
# │    └─Conv2d: 2-8                       [1, 32, 9, 16]            4,640
# │    └─MaxPool2d: 2-9                    [1, 32, 4, 6]             --
# │    └─Flatten: 2-10                     [1, 768]                  --
# │    └─Linear: 2-11                      [1, 4]                    3,076
# │    └─Linear: 2-12                      [1, 4]                    3,076
# ├─BetaVAEMark1Decoder: 1-2               [1, 6, 50, 64]            --
# │    └─Linear: 2-13                      [1, 768]                  3,840
# │    └─Upsample: 2-14                    [1, 32, 9, 12]            --
# │    └─CircularPad2d: 2-15               [1, 32, 9, 16]            --
# │    └─ConvTranspose2d: 2-16             [1, 16, 11, 18]           4,624
# │    └─Upsample: 2-17                    [1, 16, 22, 29]           --
# │    └─CircularPad2d: 2-18               [1, 16, 22, 33]           --
# │    └─ConvTranspose2d: 2-19             [1, 8, 24, 35]            1,160
# │    └─Upsample: 2-20                    [1, 8, 48, 62]            --
# │    └─CircularPad2d: 2-21               [1, 8, 48, 66]            --
# │    └─ConvTranspose2d: 2-22             [1, 6, 50, 68]            438
# ==========================================================================================
# Total params: 22,462
# Trainable params: 22,462
# Non-trainable params: 0
# Total mult-adds (M): 6.30
# ==========================================================================================
# Input size (MB): 0.08
# Forward/backward pass size (MB): 0.58
# Params size (MB): 0.09
# Estimated Total Size (MB): 0.75
# ==========================================================================================

# %%
wandb.login()
project = "TESTING BetaVAEMark1 "
config = {"epochs": 10,"lr":1e-3}


model = BetaVAEMark1(latent_dim = 7).to(device)
optimiser = torch.optim.Adam(model.parameters(), lr = config["lr"]) 

valid_recon_losses = []
valid_kl_losses = []
valid_total_losses = []

train_recon_losses = []
train_kl_losses = []
train_total_losses = []



with wandb.init(project = project, config = config) as run:
    for i in range(config["epochs"]):
        beta = 0.1 * i
        train_avg_recon_loss,train_avg_kl_loss, train_avg_total_loss = tools.train(model = model, dataloader = jz0_train_loader, device = device, optimiser = optimiser,loss_function = lambda w,x,y,z: tools.single_beta_training_loss(w,x,y,z,beta = beta), num_events = 1000)
        train_recon_losses.append(train_avg_recon_loss)
        train_kl_losses.append(train_avg_kl_loss)
        train_total_losses.append(train_avg_total_loss)

        valid_avg_recon_loss,valid_avg_kl_loss, valid_avg_total_loss = tools.valid(model = model, dataloader = jz0_valid_loader, device = device, loss_function = tools.testing_loss, num_events = 1000)
        valid_recon_losses.append(valid_avg_recon_loss)
        valid_kl_losses.append(valid_avg_kl_loss)
        valid_total_losses.append(valid_avg_total_loss)

        run.log({"Training Total Loss": train_avg_total_loss,"Training Reconstruction Loss": train_avg_recon_loss, "Training KL Loss": train_avg_kl_loss, "Validation total loss": valid_avg_total_loss,"Validation Reconstruction Loss": valid_avg_recon_loss, "Validation KL Loss": valid_avg_kl_loss})

        torch.save(model.state_dict(), f'/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/weights/BetaVAEMark1_weights_epoch{i + 1}.pth')
        
        # Saving training and validation losses
        np.save(file = f"/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/training_validation_losses/validation_total_losses.npy", arr = valid_total_losses)
        np.save(file = f"/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/training_validation_losses/training_total_losses.npy", arr = train_total_losses)

        np.save(file = f"/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/training_validation_losses/validation_recon_losses.npy", arr = valid_recon_losses)
        np.save(file = f"/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/training_validation_losses/training_recon_losses.npy", arr = train_recon_losses)

        np.save(file = f"/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/training_validation_losses/validation_kl_losses.npy", arr = valid_kl_losses)
        np.save(file = f"/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/training_validation_losses/training_kl_losses.npy", arr = train_kl_losses)
        print(f"Epoch {i + 1} Complete")

print("Network Training Complete")
# Out:
# wandb: Currently logged in as: theeinspanner (theeinspanner-ucl) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/xzcapask/atlas_ad_hllhc/wandb/run-20260129_121229-xkf7cuzv</code>
# Syncing run <strong><a href='https://wandb.ai/theeinspanner-ucl/TESTING%20BetaVAEMark1%20/runs/xkf7cuzv' target="_blank">swept-puddle-7</a></strong> to <a href='https://wandb.ai/theeinspanner-ucl/TESTING%20BetaVAEMark1%20' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/theeinspanner-ucl/TESTING%20BetaVAEMark1%20' target="_blank">https://wandb.ai/theeinspanner-ucl/TESTING%20BetaVAEMark1%20</a>
#  View run at <a href='https://wandb.ai/theeinspanner-ucl/TESTING%20BetaVAEMark1%20/runs/xkf7cuzv' target="_blank">https://wandb.ai/theeinspanner-ucl/TESTING%20BetaVAEMark1%20/runs/xkf7cuzv</a>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_218714/3294912228.py", line 27, in <module>
#     valid_avg_recon_loss,valid_avg_kl_loss, valid_avg_total_loss = tools.valid(model = model, dataloader = jz0_valid_loader, device = device, loss_function = tools.testing_loss, num_events = 1000)
#   File "/home/xzcapask/atlas_ad_hllhc/ad_tools/tools.py", line 174, in valid
#     for images in dataloader:
#   File "/home/xzcapask/atlas_ad_hllhc/env/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 708, in __next__
#     data = self._next_data()
#   File "/home/xzcapask/atlas_ad_hllhc/env/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 764, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#   File "/home/xzcapask/atlas_ad_hllhc/env/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py", line 33, in fetch
#     data.append(next(self.dataset_iter))
#   File "/home/xzcapask/atlas_ad_hllhc/ad_tools/tools.py", line 35, in __iter__
#     for eta,phi in zip(image_eta, image_phi):
#   File "/home/xzcapask/atlas_ad_hllhc/env/lib/python3.10/site-packages/torch/_tensor.py", line 1164, in __iter__
#     return iter(self.unbind(0))
# KeyboardInterrupt
#  View run <strong style="color:#cdcd00">swept-puddle-7</strong> at: <a href='https://wandb.ai/theeinspanner-ucl/TESTING%20BetaVAEMark1%20/runs/xkf7cuzv' target="_blank">https://wandb.ai/theeinspanner-ucl/TESTING%20BetaVAEMark1%20/runs/xkf7cuzv</a><br> View project at: <a href='https://wandb.ai/theeinspanner-ucl/TESTING%20BetaVAEMark1%20' target="_blank">https://wandb.ai/theeinspanner-ucl/TESTING%20BetaVAEMark1%20</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260129_121229-xkf7cuzv/logs</code>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 27
#      24 train_kl_losses.append(train_avg_kl_loss)
#      25 train_total_losses.append(train_avg_total_loss)
# ---> 27 valid_avg_recon_loss,valid_avg_kl_loss, valid_avg_total_loss = tools.valid(model = model, dataloader = jz0_valid_loader, device = device, loss_function = tools.testing_loss, num_events = 1000)
#      28 valid_recon_losses.append(valid_avg_recon_loss)
#      29 valid_kl_losses.append(valid_avg_kl_loss)
#
# File ~/atlas_ad_hllhc/ad_tools/tools.py:174, in valid(model, dataloader, device, loss_function, num_events)
#     172 total_loss = 0
#     173 with torch.no_grad():
# --> 174     for images in dataloader:
#     175         images = images.to(device)
#     176         recon_images, mu, logvar = model(images)
#
# File ~/atlas_ad_hllhc/env/lib/python3.10/site-packages/torch/utils/data/dataloader.py:708, in _BaseDataLoaderIter.__next__(self)
#     705 if self._sampler_iter is None:
#     706     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707     self._reset()  # type: ignore[call-arg]
# --> 708 data = self._next_data()
#     709 self._num_yielded += 1
#     710 if (
#     711     self._dataset_kind == _DatasetKind.Iterable
#     712     and self._IterableDataset_len_called is not None
#     713     and self._num_yielded > self._IterableDataset_len_called
#     714 ):
#
# File ~/atlas_ad_hllhc/env/lib/python3.10/site-packages/torch/utils/data/dataloader.py:764, in _SingleProcessDataLoaderIter._next_data(self)
#     762 def _next_data(self):
#     763     index = self._next_index()  # may raise StopIteration
# --> 764     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765     if self._pin_memory:
#     766         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/atlas_ad_hllhc/env/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:33, in _IterableDatasetFetcher.fetch(self, possibly_batched_index)
#      31 for _ in possibly_batched_index:
#      32     try:
# ---> 33         data.append(next(self.dataset_iter))
#      34     except StopIteration:
#      35         self.ended = True
#
# File ~/atlas_ad_hllhc/ad_tools/tools.py:35, in DatasetMaker.__iter__(self)
#      33 image_summed = torch.sum(image, dim = 0)
#      34 image_eta, image_phi = torch.where(image_summed < 2)
# ---> 35 for eta,phi in zip(image_eta, image_phi):
#      36     image[:,eta, phi] = 0
#      38 if self.transform:
#
# File ~/atlas_ad_hllhc/env/lib/python3.10/site-packages/torch/_tensor.py:1164, in Tensor.__iter__(self)
#    1155 if torch._C._get_tracing_state():
#    1156     warnings.warn(
#    1157         "Iterating over a tensor might cause the trace to be incorrect. "
#    1158         "Passing a tensor of different shape won't change the number of "
#    (...)
#    1162         stacklevel=2,
#    1163     )
# -> 1164 return iter(self.unbind(0))
#
# KeyboardInterrupt:

# %% [markdown]
# # Linear KL Anneling from $\beta = [0,1] $

# %%
model = BetaVAEMark1(latent_dim = 7).to(device)

# %%
model.load_state_dict(torch.load("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/weights/BetaVAEMark1_weights_epoch7.pth", map_location = torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
# Testing
jz0_test_mse, jz0_test_kl, jz0_test_total = tools.test(model = model,dataloader = jz0_test_loader,device = device, loss_function = tools.testing_loss)
mse_cutoff= tools.anomaly_cutoff_score(jz0_test_mse)
kl_cutoff= tools.anomaly_cutoff_score(jz0_test_kl)
total_cutoff= tools.anomaly_cutoff_score(jz0_test_total)

# %%
ggF_test_mse, ggF_test_kl, ggF_test_total = tools.test(model = model,dataloader = ggF_test_loader,device = device, loss_function = tools.testing_loss)
mse_ggf_signal = tools.signal_acceptance_rate(ggF_test_mse, mse_cutoff)
kl_ggf_signal = tools.signal_acceptance_rate(ggF_test_kl, kl_cutoff)
total_ggf_signal = tools.signal_acceptance_rate(ggF_test_total, total_cutoff)

# %%
print(f"The mse ggf singal acceptance rate is {mse_ggf_signal}")
print(f"The kl ggf singal acceptance rate is {kl_ggf_signal}")
print(f"The recon ggf singal acceptance rate is {total_ggf_signal}")
# Out:
# The mse ggf singal acceptance rate is 93.80000305175781
# The kl ggf singal acceptance rate is 76.70000457763672
# The recon ggf singal acceptance rate is 93.80000305175781

# %%
vbf_test_mse, vbf_test_kl, vbf_test_total = tools.test(model = model,dataloader = vbf_test_loader,device = device, loss_function = tools.testing_loss)
mse_vbf_signal = tools.signal_acceptance_rate(vbf_test_mse, mse_cutoff)
kl_vbf_signal = tools.signal_acceptance_rate(vbf_test_kl, kl_cutoff)
total_vbf_signal = tools.signal_acceptance_rate(vbf_test_total, total_cutoff)

# %%
print(f"The mse vbf singal acceptance rate is {mse_vbf_signal}")
print(f"The kl vbf singal acceptance rate is {kl_vbf_signal}")
print(f"The recon vbf singal acceptance rate is {total_vbf_signal}")
# Out:
# The mse vbf singal acceptance rate is 86.29999542236328
# The kl vbf singal acceptance rate is 56.599998474121094
# The recon vbf singal acceptance rate is 86.29999542236328

# %%
hs_test_mse, hs_test_kl, hs_test_total = tools.test(model = model,dataloader = hs_test_loader,device = device, loss_function = tools.testing_loss)
mse_hs_signal = tools.signal_acceptance_rate(hs_test_mse, mse_cutoff)
kl_hs_signal = tools.signal_acceptance_rate(hs_test_kl, kl_cutoff)
total_hs_signal = tools.signal_acceptance_rate(hs_test_total, total_cutoff)

# %%
print(f"The mse hs singal acceptance rate is {mse_hs_signal}")
print(f"The kl hs singal acceptance rate is {kl_hs_signal}")
print(f"The recon hs singal acceptance rate is {total_hs_signal}")
# Out:
# The mse hs singal acceptance rate is 48.69999694824219
# The kl hs singal acceptance rate is 25.5
# The recon hs singal acceptance rate is 48.69999694824219

# %%
np.save(file = "/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/signal_Acceptance_rates/BetaVAEMark1MSECutoff.npy", arr = mse_cutoff)
np.save(file = "/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/signal_Acceptance_rates/BetaVAEMark1KLCutoff.npy", arr = kl_cutoff)
np.save(file = "/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/signal_Acceptance_rates/BetaVAEMark1TotalCutoff.npy", arr = total_cutoff)

# %%
np.save(file = "/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/signal_Acceptance_rates/BetaVAEMark1MSEggFsignalrate.npy", arr = mse_ggf_signal)
np.save(file = "/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/signal_Acceptance_rates/BetaVAEMark1KLggFsignalrate.npy", arr = kl_ggf_signal)
np.save(file = "/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/signal_Acceptance_rates/BetaVAEMark1TotalggFsignalrate.npy", arr = total_ggf_signal)

np.save(file = "/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/signal_Acceptance_rates/BetaVAEMark1MSEvbfsignalrate.npy", arr = mse_vbf_signal)
np.save(file = "/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/signal_Acceptance_rates/BetaVAEMark1KLvbfsignalrate.npy", arr = kl_vbf_signal)
np.save(file = "/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/signal_Acceptance_rates/BetaVAEMark1Totalvbfsignalrate.npy", arr = total_vbf_signal)

np.save(file = "/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/signal_Acceptance_rates/BetaVAEMark1MSEhssignalrate.npy", arr = mse_hs_signal)
np.save(file = "/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/signal_Acceptance_rates/BetaVAEMark1KLhssignalrate.npy", arr = kl_hs_signal)
np.save(file = "/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/signal_Acceptance_rates/BetaVAEMark1Totalhssignalrate.npy", arr = total_hs_signal)

# %%
_,_,jz0_test_pi4_losses = tools.test(model = model,dataloader = jz0_test_pi4_loader,device = device, loss_function = tools.testing_loss)
_,_,jz0_test_pi2_losses = tools.test(model = model,dataloader = jz0_test_pi2_loader,device = device, loss_function = tools.testing_loss)
_,_,jz0_test_3pi4_losses = tools.test(model = model,dataloader = jz0_test_3pi4_loader,device = device, loss_function = tools.testing_loss)

# %%
np.save(file = "/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/phi_invariance_study/jz0pi4loss.npy", arr = jz0_test_pi4_losses)
np.save(file = "/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/phi_invariance_study/jz0pi2loss.npy", arr = jz0_test_pi2_losses)
np.save(file = "/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/phi_invariance_study/jz03pi4loss.npy", arr = jz0_test_3pi4_losses)

# %%
plt.hist(jz0_test_total, bins = 1000, range = (0,1000), histtype= "step", label = r"$\theta = 0$")
plt.hist(jz0_test_3pi4_losses, bins = 1000, range = (0,1000), histtype= "step", label = r"$\theta = \frac{3\pi}{2}$")
plt.hist(jz0_test_pi2_losses, bins = 1000, range = (0,1000), histtype= "step",label = r"$\theta = \frac{\pi}{2}$")
plt.hist(jz0_test_pi4_losses, bins = 1000, range = (0,1000), histtype= "step",label = r"$\theta = \frac{\pi}{4}$")
plt.legend()
plt.xlabel("Reconstruction Error")
plt.title("Phi Symmetry of BetaVAEMark1")
plt.savefig("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/phi_invariance_study/phi_symmetry_BetaVAEMark1.png")

# %%
jz0 = ak.from_parquet("/home/xzcapask/ad_trigger_data/JZ0_no_filter.parquet", columns = "cell_towers", row_groups=range(205,206))
jz0 = ak.to_torch(jz0.cell_towers).to(torch.float32)

# Pileup supression
for i in range(len(jz0)):
    image_summed = torch.sum(jz0[i], axis = -1)
    image_eta, image_phi = torch.where(image_summed < 2)
    for j in range(len(image_eta)):      
        jz0[i,image_eta[j], image_phi[j],:] = 0 

plt.imshow(jz0[0,:,:,0])
plt.title("Original Image")
plt.xlabel("$\phi$")
plt.ylabel("$\eta$")
plt.colorbar()
plt.savefig("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/image_generation/OriginalBetaVAEMark1Inputtestimage.png")

# %%
testimage = torch.permute(jz0[0], dims = (2,0,1)).reshape(-1,6,50,64)
testimage = testimage.to(device)
recon_image,mu,logvar = model(testimage)
plt.imshow(recon_image[0,0].cpu().detach().numpy())
plt.title("Reconstructed Image")
plt.xlabel("$\phi$")
plt.ylabel("$\eta$")
plt.colorbar()
plt.savefig("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/image_generation/ReconstructedBetaVAEMark1Inputtestimage.png")

# %%
plt.imshow(jz0[1,:,:,0])
plt.title("Original Image 2")
plt.xlabel("$\phi$")
plt.ylabel("$\eta$")
plt.colorbar()
plt.savefig("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/image_generation/OriginalBetaVAEMark1Inputtestimage2.png")

# %%
testimage = torch.permute(jz0[1], dims = (2,0,1)).reshape(-1,6,50,64)
testimage = testimage.to(device)
recon_image,mu,logvar = model(testimage)
plt.imshow(recon_image[0,0].cpu().detach().numpy())
plt.title("Reconstructed Image2")
plt.xlabel("$\phi$")
plt.ylabel("$\eta$")
plt.colorbar()
plt.savefig("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/image_generation/ReconstructedBetaVAEMark1Inputtestimage2.png")

# %% [markdown]
# # KL Annealing with upper limit of $\beta = 0.05$

# %%
model = BetaVAEMark1(latent_dim = 7).to(device)

# %%
model.load_state_dict(torch.load("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta005/weights/BetaVAEMark2beta005_weights_epoch20.pth", map_location = torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
jz0_test_mse, jz0_test_kl, jz0_test_total = tools.test(model = model,dataloader = jz0_test_loader,device = device, loss_function = tools.testing_loss)
mse_cutoff= tools.anomaly_cutoff_score(jz0_test_mse)
kl_cutoff= tools.anomaly_cutoff_score(jz0_test_kl)
total_cutoff= tools.anomaly_cutoff_score(jz0_test_total)

# %%
ggF_test_mse, ggF_test_kl, ggF_test_total = tools.test(model = model,dataloader = ggF_test_loader,device = device, loss_function = tools.testing_loss)
mse_ggf_signal = tools.signal_acceptance_rate(ggF_test_mse, mse_cutoff)
kl_ggf_signal = tools.signal_acceptance_rate(ggF_test_kl, kl_cutoff)
total_ggf_signal = tools.signal_acceptance_rate(ggF_test_total, total_cutoff)

# %%
print(f"The mse ggf singal acceptance rate is {mse_ggf_signal}")
print(f"The kl ggf singal acceptance rate is {kl_ggf_signal}")
print(f"The recon ggf singal acceptance rate is {total_ggf_signal}")
# Out:
# The mse ggf singal acceptance rate is 91.88999938964844
# The kl ggf singal acceptance rate is 76.11000061035156
# The recon ggf singal acceptance rate is 92.33999633789062

# %%
vbf_test_mse, vbf_test_kl, vbf_test_total = tools.test(model = model,dataloader = vbf_test_loader,device = device, loss_function = tools.testing_loss)
mse_vbf_signal = tools.signal_acceptance_rate(vbf_test_mse, mse_cutoff)
kl_vbf_signal = tools.signal_acceptance_rate(vbf_test_kl, kl_cutoff)
total_vbf_signal = tools.signal_acceptance_rate(vbf_test_total, total_cutoff)

# %%
print(f"The mse vbf singal acceptance rate is {mse_vbf_signal}")
print(f"The kl vbf singal acceptance rate is {kl_vbf_signal}")
print(f"The recon vbf singal acceptance rate is {total_vbf_signal}")
# Out:
# The mse vbf singal acceptance rate is 83.99000549316406
# The kl vbf singal acceptance rate is 61.31999969482422
# The recon vbf singal acceptance rate is 84.22000122070312

# %%
hs_test_mse, hs_test_kl, hs_test_total = tools.test(model = model,dataloader = hs_test_loader,device = device, loss_function = tools.testing_loss)
mse_hs_signal = tools.signal_acceptance_rate(hs_test_mse, mse_cutoff)
kl_hs_signal = tools.signal_acceptance_rate(hs_test_kl, kl_cutoff)
total_hs_signal = tools.signal_acceptance_rate(hs_test_total, total_cutoff)

# %%
print(f"The mse hs singal acceptance rate is {mse_hs_signal}")
print(f"The kl hs singal acceptance rate is {kl_hs_signal}")
print(f"The recon hs singal acceptance rate is {total_hs_signal}")
# Out:
# The mse hs singal acceptance rate is 43.88999938964844
# The kl hs singal acceptance rate is 28.229999542236328
# The recon hs singal acceptance rate is 44.27000045776367

# %%
_,_,jz0_test_pi4_losses = tools.test(model = model,dataloader = jz0_test_pi4_loader,device = device, loss_function = tools.testing_loss)
_,_,jz0_test_pi2_losses = tools.test(model = model,dataloader = jz0_test_pi2_loader,device = device, loss_function = tools.testing_loss)
_,_,jz0_test_3pi4_losses = tools.test(model = model,dataloader = jz0_test_3pi4_loader,device = device, loss_function = tools.testing_loss)

# %%
np.save(file = "/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta005/phi_invariance_study", arr = jz0_test_pi4_losses)
np.save(file = "/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta005/phi_invariance_study", arr = jz0_test_pi2_losses)
np.save(file = "/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta005/phi_invariance_study", arr = jz0_test_3pi4_losses)

# %%
plt.hist(jz0_test_total, bins = 1000, range = (0,1000), histtype= "step", label = r"$\theta = 0$")
plt.hist(jz0_test_3pi4_losses, bins = 1000, range = (0,1000), histtype= "step", label = r"$\theta = \frac{3\pi}{2}$")
plt.hist(jz0_test_pi2_losses, bins = 1000, range = (0,1000), histtype= "step",label = r"$\theta = \frac{\pi}{2}$")
plt.hist(jz0_test_pi4_losses, bins = 1000, range = (0,1000), histtype= "step",label = r"$\theta = \frac{\pi}{4}$")
plt.legend()
plt.xlabel("Reconstruction Error")
plt.title("Phi Symmetry of BetaVAEMark1")
plt.savefig("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/weighing_only_kl/Linear KL Annealing/phi_invariance_study/phi_symmetry_BetaVAEMark1.png")

# %%
jz0 = ak.from_parquet("/home/xzcapask/ad_trigger_data/JZ0_no_filter.parquet", columns = "cell_towers", row_groups=range(245,246))
jz0 = ak.to_torch(jz0.cell_towers).to(torch.float32)

# Pileup supression
for i in range(len(jz0)):
    image_summed = torch.sum(jz0[i], axis = -1)
    image_eta, image_phi = torch.where(image_summed < 2)
    for j in range(len(image_eta)):      
        jz0[i,image_eta[j], image_phi[j],:] = 0

# %%
plt.imshow(jz0[0,:,:,0])
plt.title("Original JZ0 Image 1")
plt.xlabel("$\phi$")
plt.ylabel("$\eta$")
plt.colorbar(label = "Energy GeV")
plt.savefig("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta005/image_generation/OriginalBetaVAEMark1Inputtestimage1.png")

# %%
testimage = torch.permute(jz0[0], dims = (2,0,1)).reshape(-1,6,50,64)
testimage = testimage.to(device)
recon_image,mu,logvar = model(testimage)
plt.imshow(recon_image[0,0].cpu().detach().numpy())
plt.title("Reconstructed JZ0 Image 1")
plt.xlabel("$\phi$")
plt.ylabel("$\eta$")
plt.colorbar(label = "Energy GeV")
plt.savefig("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta005/image_generation/ReconstructedBetaVAEMark1Inputtestimage1.png")

# %%
plt.imshow(jz0[1,:,:,0])
plt.title("Original JZ0 Image 2")
plt.xlabel("$\phi$")
plt.ylabel("$\eta$")
plt.colorbar()
plt.savefig("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta005/image_generation/OriginalBetaVAEMark1Inputtestimage2.png")

# %%
testimage = torch.permute(jz0[1], dims = (2,0,1)).reshape(-1,6,50,64)
testimage = testimage.to(device)
recon_image,mu,logvar = model(testimage)
plt.imshow(recon_image[0,0].cpu().detach().numpy())
plt.title("Reconstructed Image 2")
plt.xlabel("$\phi$")
plt.ylabel("$\eta$")
plt.colorbar()
plt.savefig("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta005/image_generation/ReconstructedBetaVAEMark1Inputtestimage2.png")

# %%
plt.imshow(jz0[2,:,:,0])
plt.title("Original JZ0 Image 3")
plt.xlabel("$\phi$")
plt.ylabel("$\eta$")
plt.colorbar()
plt.savefig("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta005/image_generation/OriginalBetaVAEMark1Inputtestimage3.png")

# %%
testimage = torch.permute(jz0[2], dims = (2,0,1)).reshape(-1,6,50,64)
testimage = testimage.to(device)
recon_image,mu,logvar = model(testimage)
plt.imshow(recon_image[0,0].cpu().detach().numpy())
plt.title("Reconstructed Image 3")
plt.xlabel("$\phi$")
plt.ylabel("$\eta$")
plt.colorbar()
plt.savefig("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta005/image_generation/ReconstructedBetaVAEMark1Inputtestimage3.png")

# %% [markdown]
# # $\beta = 0$

# %%
model = BetaVAEMark1(latent_dim = 7).to(device)

# %%
model.load_state_dict(torch.load("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta0/weights/BetaVAEMark1beta0_weights_epoch20.pth", map_location = torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
jz0_test_mse, jz0_test_kl, jz0_test_total = tools.test(model = model,dataloader = jz0_test_loader,device = device, loss_function = tools.testing_loss)
mse_cutoff= tools.anomaly_cutoff_score(jz0_test_mse)
kl_cutoff= tools.anomaly_cutoff_score(jz0_test_kl)
total_cutoff= tools.anomaly_cutoff_score(jz0_test_total)

# %%
ggF_test_mse, ggF_test_kl, ggF_test_total = tools.test(model = model,dataloader = ggF_test_loader,device = device, loss_function = tools.testing_loss)
mse_ggf_signal = tools.signal_acceptance_rate(ggF_test_mse, mse_cutoff)
kl_ggf_signal = tools.signal_acceptance_rate(ggF_test_kl, kl_cutoff)
total_ggf_signal = tools.signal_acceptance_rate(ggF_test_total, total_cutoff)

# %%
print(f"The mse ggf singal acceptance rate is {mse_ggf_signal}")
print(f"The kl ggf singal acceptance rate is {kl_ggf_signal}")
print(f"The recon ggf singal acceptance rate is {total_ggf_signal}")
# Out:
# The mse ggf singal acceptance rate is 92.79999542236328
# The kl ggf singal acceptance rate is 79.4000015258789
# The recon ggf singal acceptance rate is 93.5

# %%
vbf_test_mse, vbf_test_kl, vbf_test_total = tools.test(model = model,dataloader = vbf_test_loader,device = device, loss_function = tools.testing_loss)
mse_vbf_signal = tools.signal_acceptance_rate(vbf_test_mse, mse_cutoff)
kl_vbf_signal = tools.signal_acceptance_rate(vbf_test_kl, kl_cutoff)
total_vbf_signal = tools.signal_acceptance_rate(vbf_test_total, total_cutoff)

# %%
print(f"The mse vbf singal acceptance rate is {mse_vbf_signal}")
print(f"The kl vbf singal acceptance rate is {kl_vbf_signal}")
print(f"The recon vbf singal acceptance rate is {total_vbf_signal}")
# Out:
# The mse vbf singal acceptance rate is 84.69999694824219
# The kl vbf singal acceptance rate is 63.5
# The recon vbf singal acceptance rate is 86.4000015258789

# %%
hs_test_mse, hs_test_kl, hs_test_total = tools.test(model = model,dataloader = hs_test_loader,device = device, loss_function = tools.testing_loss)
mse_hs_signal = tools.signal_acceptance_rate(hs_test_mse, mse_cutoff)
kl_hs_signal = tools.signal_acceptance_rate(hs_test_kl, kl_cutoff)
total_hs_signal = tools.signal_acceptance_rate(hs_test_total, total_cutoff)

# %%
print(f"The mse hs singal acceptance rate is {mse_hs_signal}")
print(f"The kl hs singal acceptance rate is {kl_hs_signal}")
print(f"The recon hs singal acceptance rate is {total_hs_signal}")
# Out:
# The mse hs singal acceptance rate is 46.599998474121094
# The kl hs singal acceptance rate is 31.200000762939453
# The recon hs singal acceptance rate is 49.70000076293945

# %%
_,_,jz0_test_pi4_losses = tools.test(model = model,dataloader = jz0_test_pi4_loader,device = device, loss_function = tools.testing_loss)
_,_,jz0_test_pi2_losses = tools.test(model = model,dataloader = jz0_test_pi2_loader,device = device, loss_function = tools.testing_loss)
_,_,jz0_test_3pi4_losses = tools.test(model = model,dataloader = jz0_test_3pi4_loader,device = device, loss_function = tools.testing_loss)

# %%
np.save(file = "/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta0/phi_invariance_study", arr = jz0_test_pi4_losses)
np.save(file = "/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta0/phi_invariance_study", arr = jz0_test_pi2_losses)
np.save(file = "/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta0/phi_invariance_study", arr = jz0_test_3pi4_losses)

# %%
plt.hist(jz0_test_total, bins = 1000, range = (0,1000), histtype= "step", label = r"$\theta = 0$")
plt.hist(jz0_test_3pi4_losses, bins = 1000, range = (0,1000), histtype= "step", label = r"$\theta = \frac{3\pi}{2}$")
plt.hist(jz0_test_pi2_losses, bins = 1000, range = (0,1000), histtype= "step",label = r"$\theta = \frac{\pi}{2}$")
plt.hist(jz0_test_pi4_losses, bins = 1000, range = (0,1000), histtype= "step",label = r"$\theta = \frac{\pi}{4}$")
plt.legend()
plt.xlabel("Reconstruction Error")
plt.title("Phi Symmetry of BetaVAEMark1")
plt.savefig("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta0/image_generation/phi_symmetry_BetaVAEMark1.png")

# %%
jz0 = ak.from_parquet("/home/xzcapask/ad_trigger_data/JZ0_no_filter.parquet", columns = "cell_towers", row_groups=range(245,246))
jz0 = ak.to_torch(jz0.cell_towers).to(torch.float32)

# Pileup supression
for i in range(len(jz0)):
    image_summed = torch.sum(jz0[i], axis = -1)
    image_eta, image_phi = torch.where(image_summed < 2)
    for j in range(len(image_eta)):      
        jz0[i,image_eta[j], image_phi[j],:] = 0

# %%
image_summed = torch.sum(jz0, axis = -1, keepdims=True)
image_summed = torch.where(image_summed>2, image_summed, 0)

# %%
plt.imshow(jz0[0,:,:,0])
plt.title("Original JZ0 Image 1")
plt.xlabel("$\phi$")
plt.ylabel("$\eta$")
plt.colorbar(label = "Energy GeV")
plt.savefig("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta0/image_generation/OriginalBetaVAEMark1Inputtestimage1.png")

# %%
testimage = torch.permute(jz0[0], dims = (2,0,1)).reshape(-1,6,50,64)
testimage = testimage.to(device)
recon_image,mu,logvar = model(testimage)

plt.imshow(recon_image[0,0].cpu().detach().numpy())
plt.title("Reconstructed JZ0 Image 1")
plt.xlabel("$\phi$")
plt.ylabel("$\eta$")
plt.colorbar(label = "Energy GeV")
plt.savefig("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta0/image_generation/ReconstructedBetaVAEMark1Inputtestimage1.png")

logvar
# Out:
# tensor([[-10.1135, -10.2468, -10.2061, -10.0661,  -9.9518, -10.3569, -10.1913]],
#        grad_fn=<AddmmBackward0>)

# %%
plt.imshow(jz0[1,:,:,0])
plt.title("Original JZ0 Image 2")
plt.xlabel("$\phi$")
plt.ylabel("$\eta$")
plt.colorbar()
plt.savefig("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta0/image_generation/OriginalBetaVAEMark1Inputtestimage2.png")

# %%
testimage = torch.permute(jz0[1], dims = (2,0,1)).reshape(-1,6,50,64)
testimage = testimage.to(device)
recon_image,mu,logvar = model(testimage)
plt.imshow(recon_image[0,0].cpu().detach().numpy())
plt.title("Reconstructed Image 2")
plt.xlabel("$\phi$")
plt.ylabel("$\eta$")
plt.colorbar()
plt.savefig("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta0/image_generation/ReconstructedBetaVAEMark1Inputtestimage2.png")

# %%
plt.imshow(jz0[2,:,:,0])
plt.title("Original JZ0 Image 3")
plt.xlabel("$\phi$")
plt.ylabel("$\eta$")
plt.colorbar()
plt.savefig("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta0/image_generation/OriginalBetaVAEMark1Inputtestimage3.png")

# %%
testimage = torch.permute(jz0[2], dims = (2,0,1)).reshape(-1,6,50,64)
testimage = testimage.to(device)
recon_image,mu,logvar = model(testimage)
plt.imshow(recon_image[0,0].cpu().detach().numpy())
plt.title("Reconstructed Image 3")
plt.xlabel("$\phi$")
plt.ylabel("$\eta$")
plt.colorbar()
plt.savefig("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta0/image_generation/ReconstructedBetaVAEMark1Inputtestimage3.png")

# %% [markdown]
# Training Images

# %%
jz0 = ak.from_parquet("/home/xzcapask/ad_trigger_data/JZ0_no_filter.parquet", columns = "cell_towers", row_groups=range(1))
jz0 = ak.to_torch(jz0.cell_towers).to(torch.float32)

# Pileup supression
for i in range(len(jz0)):
    image_summed = torch.sum(jz0[i], axis = -1)
    image_eta, image_phi = torch.where(image_summed < 2)
    for j in range(len(image_eta)):      
        jz0[i,image_eta[j], image_phi[j],:] = 0

# %%
plt.imshow(jz0[0,:,:,0])
plt.title("Original JZ0 Image 4")
plt.xlabel("$\phi$")
plt.ylabel("$\eta$")
plt.colorbar(label = "Energy GeV")
plt.savefig("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta0/image_generation/OriginalBetaVAEMark1Inputtestimage4.png")

# %%
testimage = torch.permute(jz0[0], dims = (2,0,1)).reshape(-1,6,50,64)
testimage = testimage.to(device)
recon_image,mu,logvar = model(testimage)
plt.imshow(recon_image[0,0].cpu().detach().numpy())
plt.title("Reconstructed JZ0 Image 4")
plt.xlabel("$\phi$")
plt.ylabel("$\eta$")
plt.colorbar(label = "Energy GeV")
plt.savefig("/home/xzcapask/atlas_ad_hllhc/data/model_data/BetaVAEMark1/BetaVAEMark1beta0/image_generation/ReconstructedBetaVAEMark1Inputtestimage4.png")
